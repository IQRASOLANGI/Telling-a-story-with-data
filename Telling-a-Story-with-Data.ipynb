# %%
# Step 1: Import Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Step 3: Load Dataset
df = pd.read_csv('amazon_sales_dataset.csv')
df.head()
# Out:
#          Date     Category  Sales  Profit
# 0  2025-01-01  Electronics   2000     400
# 1  2025-01-02     Clothing   1500     300
# 2  2025-01-03  Electronics   2500     500
# 3  2025-01-04         Home   1800     350
# 4  2025-01-05     Clothing   1600     320

# %%
# Step 4: Basic Statistics
print('Average Sales:', df['Sales'].mean())
print('Total Profit:', df['Profit'].sum())
# Out:
# Average Sales: 2120.0
# Total Profit: 4420

# %%
# Step 5: Sales by Category
category_sales = df.groupby('Category')['Sales'].sum()
print(category_sales)
# Out:
# Category
# Clothing        4800
# Electronics    10300
# Home            6100
# Name: Sales, dtype: int64

# %%
# Step 6: Visualization - Bar Chart
category_sales.plot(kind='bar')
plt.title('Sales by Category')
plt.xlabel('Category')
plt.ylabel('Sales')
plt.show()

# %%
# Step 6: Visualization - Bar Chart
category_sales.plot(kind='bar')
plt.title('Sales by Category')
plt.xlabel('Category')
plt.ylabel('Sales')
plt.show()

# %%
# Step 7: Line Plot (Trend)
plt.plot(df['Date'], df['Sales'], marker='o')
plt.xticks(rotation=45)
plt.title('Sales Trend Over Time')
plt.show()

# %%
# Step 8: Scatter Plot (Sales vs Profit)
sns.scatterplot(x='Sales', y='Profit', data=df)
plt.title('Sales vs Profit')
plt.show()

# %%
# Step 9: Final Insight (Story)
print('''
Insights:
- Electronics category has highest sales
- Sales and profit are positively related
- Business is growing over time

Conclusion:
Company should focus more on Electronics and increase marketing.
''')
# Out:
# Insights:
# - Electronics category has highest sales
# - Sales and profit are positively related
# - Business is growing over time
#
# Conclusion:
# Company should focus more on Electronics and increase marketing.
